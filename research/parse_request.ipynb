# %%
import pandas as pd
from openpyxl import Workbook
from datetime import datetime
import openpyxl as opx
from openpyxl.styles import Alignment
from openpyxl.styles import PatternFill
import json

# %%
WORKBOOK = opx.load_workbook(r'request2.xlsx')
SHEET = WORKBOOK.worksheets[0]

# %%
860 / 50 * 60
# Out:
# 1032.0

# %%
df = pd.read_excel(r'request2.xlsx', index_col=0)
df.columns = range(df.shape[1])

# %%
df.head()
# Out:
#                                                                        0    \
# Отчет от
# Группа                                                          Кавказский
# Подгруппа                                                       Кавказский
# Бренд                                                               Умалат
# Дата выработки продукции:  Кавказский "Умалат" (Перекресток), 45%, кг, в/у
# Код номенклатуры в 1C                                          Н0000086159
#
#                                                                 1    \
# Отчет от
# Группа                                                          NaN
# Подгруппа                                                Кавказский
# Бренд                                                        Умалат
# Дата выработки продукции:  Кавказский "Умалат" (Окей), 45%, кг, в/у
# Код номенклатуры в 1C                                   Н0000086487
#
#                                                                    2    \
# Отчет от
# Группа                                                             NaN
# Подгруппа                                                   Кавказский
# Бренд                                                           Умалат
# Дата выработки продукции:  Кавказский "Умалат" (Тандер), 45%, кг , в/у
# Код номенклатуры в 1C                                      Н0000086542
#
#                                                                  3    \
# Отчет от
# Группа                                                           NaN
# Подгруппа                                                 Кавказский
# Бренд                                                         Умалат
# Дата выработки продукции:  Кавказский "Умалат" (Метро), 45%, кг, в/у
# Код номенклатуры в 1C                                    Н0000088745
#
#                                                               4    \
# Отчет от
# Группа                                                        NaN
# Подгруппа                                              Кавказский
# Бренд                                                      Умалат
# Дата выработки продукции:  Кавказский "Умалат", 45%, 0,37 кг, в/у
# Код номенклатуры в 1C                                 Н0000084595
#
#                                                          5    \
# Отчет от
# Группа                                                   NaN
# Подгруппа                                         Кавказский
# Бренд                                                 Глобус
# Дата выработки продукции:  Кавказский "Глобус", 45%, кг, в/у
# Код номенклатуры в 1C                            Н0000090511
#
#                                                          6    \
# Отчет от
# Группа                                                   NaN
# Подгруппа                                         Кавказский
# Бренд                                                 Умалат
# Дата выработки продукции:  Кавказский "Умалат", 45%, кг, в/у
# Код номенклатуры в 1C                            Н0000080826
#
#                                                                   7    \
# Отчет от
# Группа                                                     Черкесский
# Подгруппа                                                 Черкесский
# Бренд                                                          Умалат
# Дата выработки продукции:  Сыр Черкесский "Умалат", 45%, 0,28 кг, т/ф
# Код номенклатуры в 1C                                     Н0000094227
#
#                                                                   8    \
# Отчет от
# Группа                                                            NaN
# Подгруппа                                                 Черкесский
# Бренд                                                          Умалат
# Дата выработки продукции:  Сыр Черкесский "Умалат", 45%, кг, т/ф, ВЕС
# Код номенклатуры в 1C                                     Н0000094228
#
#                                                                       9    \
# Отчет от
# Группа                                                                NaN
# Подгруппа                                                     Черкесский
# Бренд                                                              Умалат
# Дата выработки продукции:  Сыр Черкесский "Умалат" (БИЛЛА), 45%, т/ф, ВЕС
# Код номенклатуры в 1C                                         Н0000094632
#
#                            ...                       104  \
# Отчет от                   ...
# Группа                     ...  Некондиционная продукция
# Подгруппа                  ...  Некондиционная продукция
# Бренд                      ...                       NaN
# Дата выработки продукции:  ...  Некондиционная продукция
# Код номенклатуры в 1C      ...                       NaN
#
#                                                 105                      106  \
# Отчет от
# Группа                                Полуфабрикаты                      NaN
# Подгруппа                             Полуфабрикаты                      NaN
# Бренд                                           NaN                      NaN
# Дата выработки продукции:  п/ф Рикотта промышленная  П/ф Качокавалло 45%, кг
# Код номенклатуры в 1C                   Н0000079224              Н0000083041
#
#                            107                                  108  109  \
# Отчет от
# Группа                     NaN                                  NaN  NaN
# Подгруппа                  NaN                                  NaN  NaN
# Бренд                      NaN                                  NaN  NaN
# Дата выработки продукции:  NaN  П/ф Качокавалло 45% большие головки  NaN
# Код номенклатуры в 1C      NaN                          Н0000092414  NaN
#
#                              110                        111  112  113
# Отчет от
# Группа                     Итого                     Группа  NaN  NaN
# Подгруппа                    NaN                  Подгруппа  NaN  NaN
# Бренд                        NaN                      Бренд  NaN  NaN
# Дата выработки продукции:    NaN  Дата выработки продукции:  NaN  NaN
# Код номенклатуры в 1C        NaN      Код номенклатуры в 1C  NaN  NaN
#
# [5 rows x 114 columns]

# %%
indeces = df.loc['Дата выработки продукции:'].dropna().index
df = df[indeces]

# %%
df
# Out:
#                                                                        0    \
# Отчет от
# Группа                                                          Кавказский
# Подгруппа                                                       Кавказский
# Бренд                                                               Умалат
# Дата выработки продукции:  Кавказский "Умалат" (Перекресток), 45%, кг, в/у
# Код номенклатуры в 1C                                          Н0000086159
# ...                                                                    ...
# NaN                                                                    NaN
# NaN                               Кавказский "Умалат" (Окей), 45%, кг, в/у
# Складе ГП                                                                6
# Складе Прайм                                                             6
# NaN                               Кавказский "Умалат" (Окей), 45%, кг, в/у
#
#                                                                        1    \
# Отчет от
# Группа                                                                 NaN
# Подгруппа                                                       Кавказский
# Бренд                                                               Умалат
# Дата выработки продукции:         Кавказский "Умалат" (Окей), 45%, кг, в/у
# Код номенклатуры в 1C                                          Н0000086487
# ...                                                                    ...
# NaN                                                                    NaN
# NaN                        Кавказский "Умалат" (Перекресток), 45%, кг, в/у
# Складе ГП                                                             70.7
# Складе Прайм                                                           NaN
# NaN                        Кавказский "Умалат" (Перекресток), 45%, кг, в/у
#
#                                                                      2    \
# Отчет от
# Группа                                                               NaN
# Подгруппа                                                     Кавказский
# Бренд                                                             Умалат
# Дата выработки продукции:    Кавказский "Умалат" (Тандер), 45%, кг , в/у
# Код номенклатуры в 1C                                        Н0000086542
# ...                                                                  ...
# NaN                                                                  NaN
# NaN                        Кавказский "Умалат" (половинки), 45%, кг, в/у
# Складе ГП                                                          7.768
# Складе Прайм                                                       1.946
# NaN                                                                  NaN
#
#                                                                   3    \
# Отчет от
# Группа                                                            NaN
# Подгруппа                                                  Кавказский
# Бренд                                                          Умалат
# Дата выработки продукции:   Кавказский "Умалат" (Метро), 45%, кг, в/у
# Код номенклатуры в 1C                                     Н0000088745
# ...                                                               ...
# NaN                                                               NaN
# NaN                        Кавказский "Умалат" (Тандер), 45%, кг, в/у
# Складе ГП                                                      82.017
# Складе Прайм                                                    0.002
# NaN                                                               NaN
#
#                                                               4    \
# Отчет от
# Группа                                                        NaN
# Подгруппа                                              Кавказский
# Бренд                                                      Умалат
# Дата выработки продукции:  Кавказский "Умалат", 45%, 0,37 кг, в/у
# Код номенклатуры в 1C                                 Н0000084595
# ...                                                           ...
# NaN                                                           NaN
# NaN                        Кавказский "Умалат", 45%, 0,37 кг, в/у
# Складе ГП                                                   344.1
# Складе Прайм                                                11.84
# NaN                        Кавказский "Умалат", 45%, 0,37 кг, в/у
#
#                                                          5    \
# Отчет от
# Группа                                                   NaN
# Подгруппа                                         Кавказский
# Бренд                                                 Глобус
# Дата выработки продукции:  Кавказский "Глобус", 45%, кг, в/у
# Код номенклатуры в 1C                            Н0000090511
# ...                                                      ...
# NaN                                                      NaN
# NaN                                                      NaN
# Складе ГП                                                NaN
# Складе Прайм                                             NaN
# NaN                                                      NaN
#
#                                                                  6    \
# Отчет от
# Группа                                                           NaN
# Подгруппа                                                 Кавказский
# Бренд                                                         Умалат
# Дата выработки продукции:          Кавказский "Умалат", 45%, кг, в/у
# Код номенклатуры в 1C                                    Н0000080826
# ...                                                              ...
# NaN                                                              NaN
# NaN                        Качокавалло "Ungrande", 45%, 0,26 кг, в/у
# Складе ГП                                                     849.68
# Складе Прайм                                                     5.2
# NaN                                                              NaN
#
#                                                                   7    \
# Отчет от
# Группа                                                     Черкесский
# Подгруппа                                                 Черкесский
# Бренд                                                          Умалат
# Дата выработки продукции:  Сыр Черкесский "Умалат", 45%, 0,28 кг, т/ф
# Код номенклатуры в 1C                                     Н0000094227
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# Складе ГП                                                         NaN
# Складе Прайм                                                      NaN
# NaN                                                               NaN
#
#                                                                   8    \
# Отчет от
# Группа                                                            NaN
# Подгруппа                                                 Черкесский
# Бренд                                                          Умалат
# Дата выработки продукции:  Сыр Черкесский "Умалат", 45%, кг, т/ф, ВЕС
# Код номенклатуры в 1C                                     Н0000094228
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# Складе ГП                                                         NaN
# Складе Прайм                                                      NaN
# NaN                                                               NaN
#
#                                                                       9    \
# Отчет от
# Группа                                                                NaN
# Подгруппа                                                     Черкесский
# Бренд                                                              Умалат
# Дата выработки продукции:  Сыр Черкесский "Умалат" (БИЛЛА), 45%, т/ф, ВЕС
# Код номенклатуры в 1C                                         Н0000094632
# ...                                                                   ...
# NaN                                                                   NaN
# NaN                                                                   NaN
# Складе ГП                                                             NaN
# Складе Прайм                                                          NaN
# NaN                                                                   NaN
#
#                            ...  \
# Отчет от                   ...
# Группа                     ...
# Подгруппа                  ...
# Бренд                      ...
# Дата выработки продукции:  ...
# Код номенклатуры в 1C      ...
# ...                        ...
# NaN                        ...
# NaN                        ...
# Складе ГП                  ...
# Складе Прайм               ...
# NaN                        ...
#
#                                                                         99   \
# Отчет от
# Группа                                                                  NaN
# Подгруппа                                                             Масло
# Бренд                                                                Умалат
# Дата выработки продукции:        Масло сливочное "Умалат", 72,5%, 2 кг, к/к
# Код номенклатуры в 1C                                           Н0000084378
# ...                                                                     ...
# NaN                                                                     NaN
# NaN                        Сулугуни "Маркет Перекресток", 45%, 0,28 кг, т/ф
# Складе ГП                                                            120.96
# Складе Прайм                                                            NaN
# NaN                        Сулугуни "Маркет Перекресток", 45%, 0,28 кг, т/ф
#
#                                                                          100  \
# Отчет от
# Группа                                                                   NaN
# Подгруппа                                                              Масло
# Бренд                                                                    NaN
# Дата выработки продукции:  Масло сладко-сливочное традиционное 84%, 2 кг,...
# Код номенклатуры в 1C                                            Н0000093768
# ...                                                                      ...
# NaN                                                                      NaN
# NaN                                                                      NaN
# Складе ГП                                                                NaN
# Складе Прайм                                                             NaN
# NaN                                                                      NaN
#
#                                                                          101  \
# Отчет от
# Группа                                                                   NaN
# Подгруппа                                                              Масло
# Бренд                                                              Unagrande
# Дата выработки продукции:  Масло сладко-сливочное традиционное "Unagrande...
# Код номенклатуры в 1C                                            Н0000094161
# ...                                                                      ...
# NaN                                                                      NaN
# NaN                                                                      NaN
# Складе ГП                                                                NaN
# Складе Прайм                                                             NaN
# NaN                                                                      NaN
#
#                                                                          102  \
# Отчет от
# Группа                                                                   NaN
# Подгруппа                                                              Масло
# Бренд                                                              Unagrande
# Дата выработки продукции:  Масло сладко-сливочное традиционное солёное "U...
# Код номенклатуры в 1C                                            Н0000094162
# ...                                                                      ...
# NaN                                                                      NaN
# NaN                                                                      NaN
# Складе ГП                                                                NaN
# Складе Прайм                                                             NaN
# NaN                                                                      NaN
#
#                                                                          103  \
# Отчет от
# Группа                                                                   NaN
# Подгруппа                                                              Масло
# Бренд                                                                    NaN
# Дата выработки продукции:  Масло сладко-сливочное Традиционное, 82,5%, 2 ...
# Код номенклатуры в 1C                                            Н0000088626
# ...                                                                      ...
# NaN                                                                      NaN
# NaN                                                            Сырная крошка
# Складе ГП                                                               70.4
# Складе Прайм                                                             NaN
# NaN                                                                      NaN
#
#                                                          104  \
# Отчет от
# Группа                              Некондиционная продукция
# Подгруппа                           Некондиционная продукция
# Бренд                                                    NaN
# Дата выработки продукции:           Некондиционная продукция
# Код номенклатуры в 1C                                    NaN
# ...                                                      ...
# NaN                                                      NaN
# NaN                        Четук "Умалат", 45%, 0,37 кг, в/у
# Складе ГП                                              136.6
# Складе Прайм                                             NaN
# NaN                        Четук "Умалат", 45%, 0,37 кг, в/у
#
#                                                          105  \
# Отчет от
# Группа                                         Полуфабрикаты
# Подгруппа                                      Полуфабрикаты
# Бренд                                                    NaN
# Дата выработки продукции:           п/ф Рикотта промышленная
# Код номенклатуры в 1C                            Н0000079224
# ...                                                      ...
# NaN                                                      NaN
# NaN                        Чечил "Умалат", 43%, 0,19 кг, т/ф
# Складе ГП                                             121.41
# Складе Прайм                                            2.28
# NaN                                                      NaN
#
#                                                106  \
# Отчет от
# Группа                                         NaN
# Подгруппа                                      NaN
# Бренд                                          NaN
# Дата выработки продукции:  П/ф Качокавалло 45%, кг
# Код номенклатуры в 1C                  Н0000083041
# ...                                            ...
# NaN                                            NaN
# NaN                                            NaN
# Складе ГП                                      NaN
# Складе Прайм                                   NaN
# NaN                                            NaN
#
#                                                            108  \
# Отчет от
# Группа                                                     NaN
# Подгруппа                                                  NaN
# Бренд                                                      NaN
# Дата выработки продукции:  П/ф Качокавалло 45% большие головки
# Код номенклатуры в 1C                              Н0000092414
# ...                                                        ...
# NaN                                                        NaN
# NaN                                                        NaN
# Складе ГП                                                  NaN
# Складе Прайм                                               NaN
# NaN                                                        NaN
#
#                                                  111
# Отчет от
# Группа                                        Группа
# Подгруппа                                  Подгруппа
# Бренд                                          Бренд
# Дата выработки продукции:  Дата выработки продукции:
# Код номенклатуры в 1C          Код номенклатуры в 1C
# ...                                              ...
# NaN                                              NaN
# NaN                                              NaN
# Складе ГП                                   -1637.35
# Складе Прайм                                  804.09
# NaN                                              NaN
#
# [306 rows x 109 columns]

# %%
tmp = df.loc[['Дата выработки продукции:', 'Заявлено всего, кг:', 'Фактические остатки на складах - Заявлено, кг:', 'Нормативные остатки, кг']].fillna(0)

# %%
tmp
# Out:
#                                                                                             0    \
# Отчет от
# Дата выработки продукции:                       Кавказский "Умалат" (Перекресток), 45%, кг, в/у
# Заявлено всего, кг:                                                                       356.4
# Фактические остатки на складах - Заявлено, кг:                                           1098.6
# Нормативные остатки, кг                                                                 931.987
#
#                                                                                      1    \
# Отчет от
# Дата выработки продукции:                       Кавказский "Умалат" (Окей), 45%, кг, в/у
# Заявлено всего, кг:                                                                  225
# Фактические остатки на складах - Заявлено, кг:                                      -225
# Нормативные остатки, кг                                                           91.603
#
#                                                                                         2    \
# Отчет от
# Дата выработки продукции:                       Кавказский "Умалат" (Тандер), 45%, кг , в/у
# Заявлено всего, кг:                                                                     759
# Фактические остатки на складах - Заявлено, кг:                                          213
# Нормативные остатки, кг                                                             680.221
#
#                                                                                       3    \
# Отчет от
# Дата выработки продукции:                       Кавказский "Умалат" (Метро), 45%, кг, в/у
# Заявлено всего, кг:                                                                   102
# Фактические остатки на складах - Заявлено, кг:                                          0
# Нормативные остатки, кг                                                           105.966
#
#                                                                                    4    \
# Отчет от
# Дата выработки продукции:                       Кавказский "Умалат", 45%, 0,37 кг, в/у
# Заявлено всего, кг:                                                            1329.78
# Фактические остатки на складах - Заявлено, кг:                                   -77.7
# Нормативные остатки, кг                                                         747.47
#
#                                                                               5    \
# Отчет от
# Дата выработки продукции:                       Кавказский "Глобус", 45%, кг, в/у
# Заявлено всего, кг:                                                            42
# Фактические остатки на складах - Заявлено, кг:                                -42
# Нормативные остатки, кг                                                   52.2857
#
#                                                                               6    \
# Отчет от
# Дата выработки продукции:                       Кавказский "Умалат", 45%, кг, в/у
# Заявлено всего, кг:                                                            28
# Фактические остатки на складах - Заявлено, кг:                                -16
# Нормативные остатки, кг                                                   858.545
#
#                                                                                        7    \
# Отчет от
# Дата выработки продукции:                       Сыр Черкесский "Умалат", 45%, 0,28 кг, т/ф
# Заявлено всего, кг:                                                                 732.48
# Фактические остатки на складах - Заявлено, кг:                                      -20.16
# Нормативные остатки, кг                                                            588.053
#
#                                                                                        8    \
# Отчет от
# Дата выработки продукции:                       Сыр Черкесский "Умалат", 45%, кг, т/ф, ВЕС
# Заявлено всего, кг:                                                                  53.04
# Фактические остатки на складах - Заявлено, кг:                                       -3.76
# Нормативные остатки, кг                                                            121.541
#
#                                                                                            9    \
# Отчет от
# Дата выработки продукции:                       Сыр Черкесский "Умалат" (БИЛЛА), 45%, т/ф, ВЕС
# Заявлено всего, кг:                                                                          0
# Фактические остатки на складах - Заявлено, кг:                                               0
# Нормативные остатки, кг                                                                124.659
#
#                                                 ...  \
# Отчет от                                        ...
# Дата выработки продукции:                       ...
# Заявлено всего, кг:                             ...
# Фактические остатки на складах - Заявлено, кг:  ...
# Нормативные остатки, кг                         ...
#
#                                                                                        99   \
# Отчет от
# Дата выработки продукции:                       Масло сливочное "Умалат", 72,5%, 2 кг, к/к
# Заявлено всего, кг:                                                                    426
# Фактические остатки на складах - Заявлено, кг:                                         642
# Нормативные остатки, кг                                                            453.143
#
#                                                                                               100  \
# Отчет от
# Дата выработки продукции:                       Масло сладко-сливочное традиционное 84%, 2 кг,...
# Заявлено всего, кг:                                                                             0
# Фактические остатки на складах - Заявлено, кг:                                                582
# Нормативные остатки, кг                                                                   96.7619
#
#                                                                                               101  \
# Отчет от
# Дата выработки продукции:                       Масло сладко-сливочное традиционное "Unagrande...
# Заявлено всего, кг:                                                                            99
# Фактические остатки на складах - Заявлено, кг:                                                219
# Нормативные остатки, кг                                                                       114
#
#                                                                                               102  \
# Отчет от
# Дата выработки продукции:                       Масло сладко-сливочное традиционное солёное "U...
# Заявлено всего, кг:                                                                           141
# Фактические остатки на складах - Заявлено, кг:                                                261
# Нормативные остатки, кг                                                                   159.238
#
#                                                                                               103  \
# Отчет от
# Дата выработки продукции:                       Масло сладко-сливочное Традиционное, 82,5%, 2 ...
# Заявлено всего, кг:                                                                           390
# Фактические остатки на складах - Заявлено, кг:                                                360
# Нормативные остатки, кг                                                                   250.286
#
#                                                                      104  \
# Отчет от
# Дата выработки продукции:                       Некондиционная продукция
# Заявлено всего, кг:                                                    0
# Фактические остатки на складах - Заявлено, кг:                         0
# Нормативные остатки, кг                                                0
#
#                                                                      105  \
# Отчет от
# Дата выработки продукции:                       п/ф Рикотта промышленная
# Заявлено всего, кг:                                                    0
# Фактические остатки на складах - Заявлено, кг:                         0
# Нормативные остатки, кг                                                0
#
#                                                                     106  \
# Отчет от
# Дата выработки продукции:                       П/ф Качокавалло 45%, кг
# Заявлено всего, кг:                                                   0
# Фактические остатки на складах - Заявлено, кг:                        0
# Нормативные остатки, кг                                               0
#
#                                                                                 108  \
# Отчет от
# Дата выработки продукции:                       П/ф Качокавалло 45% большие головки
# Заявлено всего, кг:                                                               0
# Фактические остатки на складах - Заявлено, кг:                                    0
# Нормативные остатки, кг                                                           0
#
#                                                                                            111
# Отчет от
# Дата выработки продукции:                                            Дата выработки продукции:
# Заявлено всего, кг:                                                        Заявлено всего, кг:
# Фактические остатки на складах - Заявлено, кг:  Фактические остатки на складах - Заявлено, кг:
# Нормативные остатки, кг                                                Нормативные остатки, кг
#
# [4 rows x 109 columns]

# %%
tmp = df.dropna(thresh=limit-2)
tmp.dropna(how='all', axis='columns')
# Out:
#    Ведомость по заказам покупателей                             Unnamed: 2  \
# 7                        Контрагент  Кавказский "Глобус", 45%, кг, в/у, кг
# 9                               NaN        Количество (в базовых единицах)
# 10                              NaN                                 Приход
# 44                             Итог                                     42
#
#                                Unnamed: 3  \
# 7   Кавказский "Глобус", 45%, кг, в/у, кг
# 9         Количество (в базовых единицах)
# 10                                 Приход
# 44                                     42
#
#                                        Unnamed: 4  \
# 7   Кавказский "Умалат" (Метро), 45%, кг, в/у, кг
# 9                 Количество (в базовых единицах)
# 10                                         Приход
# 44                                             81
#
#                                        Unnamed: 5  \
# 7   Кавказский "Умалат" (Метро), 45%, кг, в/у, кг
# 9                 Количество (в базовых единицах)
# 10                                         Приход
# 44                                             81
#
#                                       Unnamed: 6  \
# 7   Кавказский "Умалат" (Окей), 45%, кг, в/у, кг
# 9                Количество (в базовых единицах)
# 10                                        Приход
# 44                                           225
#
#                                       Unnamed: 7  \
# 7   Кавказский "Умалат" (Окей), 45%, кг, в/у, кг
# 9                Количество (в базовых единицах)
# 10                                        Приход
# 44                                           225
#
#                                            Unnamed: 8  \
# 7   Кавказский "Умалат" (Перекресток), 45%, кг, в/...
# 9                     Количество (в базовых единицах)
# 10                                             Приход
# 44                                              260.7
#
#                                            Unnamed: 9  \
# 7   Кавказский "Умалат" (Перекресток), 45%, кг, в/...
# 9                     Количество (в базовых единицах)
# 10                                             Приход
# 44                                              260.7
#
#                                          Unnamed: 10  ...  \
# 7   Кавказский "Умалат" (Тандер), 45%, кг , в/у , кг  ...
# 9                    Количество (в базовых единицах)  ...
# 10                                            Приход  ...
# 44                                               708  ...
#
#                                          Unnamed: 155  \
# 7   Сулугуни палочки "Умалат", 45%, 0,12 кг, т/ф (...
# 9                     Количество (в базовых единицах)
# 10                                             Приход
# 44                                              706.2
#
#                                       Unnamed: 156  \
# 7   Сыр Черкесский "Умалат", 45%, 0,28 кг, т/ф, кг
# 9                  Количество (в базовых единицах)
# 10                                          Приход
# 44                                           515.2
#
#                                       Unnamed: 157  \
# 7   Сыр Черкесский "Умалат", 45%, 0,28 кг, т/ф, кг
# 9                  Количество (в базовых единицах)
# 10                                          Приход
# 44                                           515.2
#
#                                       Unnamed: 158  \
# 7   Сыр Черкесский "Умалат", 45%, кг, т/ф, ВЕС, кг
# 9                  Количество (в базовых единицах)
# 10                                          Приход
# 44                                            4.32
#
#                                       Unnamed: 159  \
# 7   Сыр Черкесский "Умалат", 45%, кг, т/ф, ВЕС, кг
# 9                  Количество (в базовых единицах)
# 10                                          Приход
# 44                                            4.32
#
#                                   Unnamed: 160  \
# 7   Творожный "Pretto", 65%, 0,18 кг, пл/с, кг
# 9              Количество (в базовых единицах)
# 10                                      Приход
# 44                                      224.64
#
#                                   Unnamed: 161  \
# 7   Творожный "Pretto", 65%, 0,18 кг, пл/с, кг
# 9              Количество (в базовых единицах)
# 10                                      Приход
# 44                                      224.64
#
#                              Unnamed: 162  \
# 7   Четук "Умалат", 45%, 0,37 кг, в/у, кг
# 9         Количество (в базовых единицах)
# 10                                 Приход
# 44                                 178.34
#
#                              Unnamed: 163                     Unnamed: 164
# 7   Четук "Умалат", 45%, 0,37 кг, в/у, кг                             Итог
# 9         Количество (в базовых единицах)  Количество (в базовых единицах)
# 10                                 Приход                           Приход
# 44                                 178.34                          47242.9
#
# [4 rows x 164 columns]

# %%
sku_list = tmp.iloc[0].dropna()

# %%
sku_name = [x for x in list(sku_list) if 'Контрагент' not in x and 'Итог' not in x]

# %%
sku_name = list(sku_list[1:-1])

# %%
sku_volumes = list(tmp.iloc[-1].dropna()[1:-1])

# %%
list(zip(sku_name, sku_volumes))
# Out:
# [('Кавказский "Глобус", 45%, кг, в/у, кг', 42),
#  ('Кавказский "Глобус", 45%, кг, в/у, кг', 42),
#  ('Кавказский "Умалат" (Метро), 45%, кг, в/у, кг', 81),
#  ('Кавказский "Умалат" (Метро), 45%, кг, в/у, кг', 81),
#  ('Кавказский "Умалат" (Окей), 45%, кг, в/у, кг', 225),
#  ('Кавказский "Умалат" (Окей), 45%, кг, в/у, кг', 225),
#  ('Кавказский "Умалат" (Перекресток), 45%, кг, в/у, кг', 260.7),
#  ('Кавказский "Умалат" (Перекресток), 45%, кг, в/у, кг', 260.7),
#  ('Кавказский "Умалат" (Тандер), 45%, кг , в/у , кг', 708),
#  ('Кавказский "Умалат" (Тандер), 45%, кг , в/у , кг', 708),
#  ('Кавказский "Умалат", 45%, 0,37 кг, в/у, кг', 740.74),
#  ('Кавказский "Умалат", 45%, 0,37 кг, в/у, кг', 740.74),
#  ('Кавказский "Умалат", 45%, кг, в/у, кг', 6),
#  ('Кавказский "Умалат", 45%, кг, в/у, кг', 6),
#  ('Качокавалло "Unagrande" (ОК), 45%, кг, кг', 17.1),
#  ('Качокавалло "Unagrande" (ОК), 45%, кг, кг', 17.1),
#  ('Качокавалло "Unagrande", 45%, 0,26 кг, в/у, (8 шт), кг', 214.24),
#  ('Качокавалло "Unagrande", 45%, 0,26 кг, в/у, (8 шт), кг', 214.24),
#  ('Качокавалло "Unagrande", 45%, кг, кг', 21.4),
#  ('Качокавалло "Unagrande", 45%, кг, кг', 21.4),
#  ('Качорикотта "Unagrande", 45%, 0,37 кг, в/у, кг', 74),
#  ('Качорикотта "Unagrande", 45%, 0,37 кг, в/у, кг', 74),
#  ('Кремчиз "Pretto", 75%, 0,2 кг, пл/с, кг', 157.2),
#  ('Кремчиз "Pretto", 75%, 0,2 кг, пл/с, кг', 157.2),
#  ('Кремчиз "Unagrande", 70%, 0,18 кг, пл/с, кг', 655.56),
#  ('Кремчиз "Unagrande", 70%, 0,18 кг, пл/с, кг', 655.56),
#  ('Кремчиз "Unagrande", 70%, 0,5 кг, пл/с, кг', 57),
#  ('Кремчиз "Unagrande", 70%, 0,5 кг, пл/с, кг', 57),
#  ('Маскарпоне "Pretto", 80%, 0,25 кг, пл/с, кг', 2556),
#  ('Маскарпоне "Pretto", 80%, 0,25 кг, пл/с, кг', 2556),
#  ('Маскарпоне "Pretto", 80%, 0,5 кг, пл/с, кг', 1044),
#  ('Маскарпоне "Pretto", 80%, 0,5 кг, пл/с, кг', 1044),
#  ('Маскарпоне "Unagrande", 80%, 0,25 кг, пл/с, кг', 1534.5),
#  ('Маскарпоне "Unagrande", 80%, 0,25 кг, пл/с, кг', 1534.5),
#  ('Маскарпоне "Ungrande", 80%, 0,5 кг, пл/с, кг', 285),
#  ('Маскарпоне "Ungrande", 80%, 0,5 кг, пл/с, кг', 285),
#  ('Маскарпоне "Глобус", 80%, 0,25 кг, пл/с, кг', 21),
#  ('Маскарпоне "Глобус", 80%, 0,25 кг, пл/с, кг', 21),
#  ('Маскарпоне "Красная птица", 80%,  0,25 кг, пл/с, (6 шт), кг', 216),
#  ('Маскарпоне "Красная птица", 80%,  0,25 кг, пл/с, (6 шт), кг', 216),
#  ('Маскарпоне с шоколадом "Unagrande", 50%, 0,18 кг, пл/с, кг', 126.36),
#  ('Маскарпоне с шоколадом "Unagrande", 50%, 0,18 кг, пл/с, кг', 126.36),
#  ('Маскарпоне с шоколадом "Бонджорно", 50%, 0,2 кг, пл/с, кг', 24),
#  ('Маскарпоне с шоколадом "Бонджорно", 50%, 0,2 кг, пл/с, кг', 24),
#  ('Масло сладко-сливочное традиционное "Unagrande", 82,5%, 0,5 кг, к/к, кг',
#   75),
#  ('Масло сладко-сливочное традиционное "Unagrande", 82,5%, 0,5 кг, к/к, кг',
#   75),
#  ('Масло сладко-сливочное традиционное солёное "Unagrande", 82,5%, 0,5 кг, к/к, кг',
#   123),
#  ('Масло сладко-сливочное традиционное солёное "Unagrande", 82,5%, 0,5 кг, к/к, кг',
#   123),
#  ('Масло сладко-сливочное Традиционное, 82,5%, 2 кг, к/к, кг', 192),
#  ('Масло сладко-сливочное Традиционное, 82,5%, 2 кг, к/к, кг', 192),
#  ('Масло сливочное "Умалат", 72,5%  0,5 кг, к/к, кг', 426),
#  ('Масло сливочное "Умалат", 72,5%  0,5 кг, к/к, кг', 426),
#  ('Масло сливочное "Умалат", 72,5%, 2 кг, к/к, кг', 342),
#  ('Масло сливочное "Умалат", 72,5%, 2 кг, к/к, кг', 342),
#  ('Моцарелла "Pretto" (для бутербродов), 45%, 0,2 кг, т/ф, (9 шт), кг',
#   2563.2),
#  ('Моцарелла "Pretto" (для бутербродов), 45%, 0,2 кг, т/ф, (9 шт), кг',
#   2563.2),
#  ('Моцарелла "Pretto", 45%, 1,2 кг, в/у, кг', 1008),
#  ('Моцарелла "Pretto", 45%, 1,2 кг, в/у, кг', 1008),
#  ('Моцарелла "Unagrande", 45%, 0,12 кг, ф/п (кубики), кг', 25.2),
#  ('Моцарелла "Unagrande", 45%, 0,12 кг, ф/п (кубики), кг', 25.2),
#  ('Моцарелла "Unagrande", 45%, 3 кг, пл/л, кг', 270),
#  ('Моцарелла "Unagrande", 45%, 3 кг, пл/л, кг', 270),
#  ('Моцарелла без лактозы для сэндвичей "Unagrande", 45%, 0,28 кг, т/ф, кг',
#   20.72),
#  ('Моцарелла без лактозы для сэндвичей "Unagrande", 45%, 0,28 кг, т/ф, кг',
#   20.72),
#  ('Моцарелла в воде Фиор Ди Латте без лактозы "Unagrande", 45%, 0,125 кг, ф/п, (8 шт), кг',
#   79),
#  ('Моцарелла в воде Фиор Ди Латте без лактозы "Unagrande", 45%, 0,125 кг, ф/п, (8 шт), кг',
#   79),
#  ('Моцарелла в воде Чильеджина без лактозы "Unagrande", 45%, 0,125 кг, ф/п, кг',
#   2),
#  ('Моцарелла в воде Чильеджина без лактозы "Unagrande", 45%, 0,125 кг, ф/п, кг',
#   2),
#  ('Моцарелла Грандиоза в воде "Unagrande", 50%, 0,2 кг, ф/п, кг', 116.8),
#  ('Моцарелла Грандиоза в воде "Unagrande", 50%, 0,2 кг, ф/п, кг', 116.8),
#  ('Моцарелла для пиццы "Pretto", 45 %, 0,46 кг, т/ф, (8 шт), кг', 246.56),
#  ('Моцарелла для пиццы "Pretto", 45 %, 0,46 кг, т/ф, (8 шт), кг', 246.56),
#  ('Моцарелла для пиццы "Unagrande", 45%, 0,46 кг, в/у, (8 шт), кг', 1799.52),
#  ('Моцарелла для пиццы "Unagrande", 45%, 0,46 кг, в/у, (8 шт), кг', 1799.52),
#  ('Моцарелла для пиццы «Fine Life», 45%, 0,37 кг, т/ф, (6 шт), кг', 46.62),
#  ('Моцарелла для пиццы «Fine Life», 45%, 0,37 кг, т/ф, (6 шт), кг', 46.62),
#  ('Моцарелла для сэндвичей "Unagrande", 45%, 0,28 кг, т/ф, (8 шт), кг',
#   266.56),
#  ('Моцарелла для сэндвичей "Unagrande", 45%, 0,28 кг, т/ф, (8 шт), кг',
#   266.56),
#  ('Моцарелла палочки "Unagrande", 45%, 0,12 кг, т/ф, кг', 222.6),
#  ('Моцарелла палочки "Unagrande", 45%, 0,12 кг, т/ф, кг', 222.6),
#  ('Моцарелла палочки "Бонджорно", 45%, 0,12 кг, т/ф, кг', 3.6),
#  ('Моцарелла палочки "Бонджорно", 45%, 0,12 кг, т/ф, кг', 3.6),
#  ('Моцарелла сердечки в воде "Unagrande", 45%, 0,125 кг, ф/п, (8 шт), кг', 28),
#  ('Моцарелла сердечки в воде "Unagrande", 45%, 0,125 кг, ф/п, (8 шт), кг', 28),
#  ('Моцарелла Фиор ди латте в воде "Fine Life", 45%, 0,125 кг, ф/п, кг', 43.5),
#  ('Моцарелла Фиор ди латте в воде "Fine Life", 45%, 0,125 кг, ф/п, кг', 43.5),
#  ('Моцарелла Фиор Ди Латте в воде "Pretto", 45%, 0,1 кг, ф/п, (8 шт), кг',
#   387.2),
#  ('Моцарелла Фиор Ди Латте в воде "Pretto", 45%, 0,1 кг, ф/п, (8 шт), кг',
#   387.2),
#  ('Моцарелла Фиор Ди Латте в воде "Pretto", 45%, 0,125 кг, ф/п, (8 шт), кг',
#   17),
#  ('Моцарелла Фиор Ди Латте в воде "Pretto", 45%, 0,125 кг, ф/п, (8 шт), кг',
#   17),
#  ('Моцарелла Фиор ди латте в воде "Unagrande", 50%, 0,125 кг, ф/п, (8 шт), кг',
#   373),
#  ('Моцарелла Фиор ди латте в воде "Unagrande", 50%, 0,125 кг, ф/п, (8 шт), кг',
#   373),
#  ('Моцарелла Фиор ди Латте в воде "Ваш выбор", 50%, 0,1 кг, ф/п, кг', 99.6),
#  ('Моцарелла Фиор ди Латте в воде "Ваш выбор", 50%, 0,1 кг, ф/п, кг', 99.6),
#  ('Моцарелла Фиор ди Латте в воде "Красная птица", 45%, 0,125 кг, ф/п, кг',
#   84),
#  ('Моцарелла Фиор ди Латте в воде "Красная птица", 45%, 0,125 кг, ф/п, кг',
#   84),
#  ('Моцарелла Чильеджина в воде "Fine Life", 45%, 0,125 кг, ф/п, кг', 34.5),
#  ('Моцарелла Чильеджина в воде "Fine Life", 45%, 0,125 кг, ф/п, кг', 34.5),
#  ('Моцарелла Чильеджина в воде "Pretto", 45%, 0,1 кг, ф/п, (8 шт), кг', 622.4),
#  ('Моцарелла Чильеджина в воде "Pretto", 45%, 0,1 кг, ф/п, (8 шт), кг', 622.4),
#  ('Моцарелла Чильеджина в воде "Unagrande", 50%, 0,125, ф/п, (8 шт), кг',
#   1112),
#  ('Моцарелла Чильеджина в воде "Unagrande", 50%, 0,125, ф/п, (8 шт), кг',
#   1112),
#  ('Моцарелла Чильеджина в воде "Ваш выбор", 50%, 0,1 кг, ф/п, кг', 157.2),
#  ('Моцарелла Чильеджина в воде "Ваш выбор", 50%, 0,1 кг, ф/п, кг', 157.2),
#  ('Моцарелла Чильеджина в воде "Красная птица", 45%, 0,125 кг, ф/п, кг', 91.5),
#  ('Моцарелла Чильеджина в воде "Красная птица", 45%, 0,125 кг, ф/п, кг', 91.5),
#  ('Моцарелла шары "Metro Chef", 45%, кг, в/у, кг', 414),
#  ('Моцарелла шары "Metro Chef", 45%, кг, в/у, кг', 414),
#  ('Рикотта "Pretto" (зернистая), 30%, 0,37 кг, в/у, кг', 165.76),
#  ('Рикотта "Pretto" (зернистая), 30%, 0,37 кг, в/у, кг', 165.76),
#  ('Рикотта "Pretto", 45%, 0,2 кг, пл/с, кг', 2115.6),
#  ('Рикотта "Pretto", 45%, 0,2 кг, пл/с, кг', 2115.6),
#  ('Рикотта "Pretto", 45%, 0,5 кг, пл/с, кг', 17475),
#  ('Рикотта "Pretto", 45%, 0,5 кг, пл/с, кг', 17475),
#  ('Рикотта "Unagrande Professionale", 45%, 0,5 кг, пл/с, кг', 21),
#  ('Рикотта "Unagrande Professionale", 45%, 0,5 кг, пл/с, кг', 21),
#  ('Рикотта "Unagrande", 50%, 0,25 кг, пл/с, кг', 706.5),
#  ('Рикотта "Unagrande", 50%, 0,25 кг, пл/с, кг', 706.5),
#  ('Рикотта "Unagrande", 50%, 0,5 кг, пл/с, кг', 30),
#  ('Рикотта "Unagrande", 50%, 0,5 кг, пл/с, кг', 30),
#  ('Рикотта "Глобус", 45%, 0,25 кг, пл/с, кг', 7.5),
#  ('Рикотта "Глобус", 45%, 0,25 кг, пл/с, кг', 7.5),
#  ('Рикотта "Красная птица", 30%,  0,25 кг, пл/с (6 шт), кг', 145.5),
#  ('Рикотта "Красная птица", 30%,  0,25 кг, пл/с (6 шт), кг', 145.5),
#  ('Рикотта с ванилью "Бонджорно", 30%, 0,2 кг, пл/с, кг', 75.6),
#  ('Рикотта с ванилью "Бонджорно", 30%, 0,2 кг, пл/с, кг', 75.6),
#  ('Рикотта с шоколадом "Unagrande", 30%, 0,14 кг, пл/с, кг', 162.96),
#  ('Рикотта с шоколадом "Unagrande", 30%, 0,14 кг, пл/с, кг', 162.96),
#  ('Рикотта с шоколадом "Unagrande", 30%, 0,18 кг, пл/с, кг', 367.2),
#  ('Рикотта с шоколадом "Unagrande", 30%, 0,18 кг, пл/с, кг', 367.2),
#  ('Рикотта с шоколадом "Бонджорно", 30%, 0,2 кг, пл/с, кг', 46.8),
#  ('Рикотта с шоколадом "Бонджорно", 30%, 0,2 кг, пл/с, кг', 46.8),
#  ('Рикотта сицилийская "Unagrande", 55%, 0,3 кг, пл/с, кг', 297),
#  ('Рикотта сицилийская "Unagrande", 55%, 0,3 кг, пл/с, кг', 297),
#  ('Рикотта шоколадно-ореховая "Бонджорно", 35%, 0,2 кг, пл/с, кг', 42),
#  ('Рикотта шоколадно-ореховая "Бонджорно", 35%, 0,2 кг, пл/с, кг', 42),
#  ('Робиола "Unagrande", 65%, 0,18 кг, пл/с, кг', 61.56),
#  ('Робиола "Unagrande", 65%, 0,18 кг, пл/с, кг', 61.56),
#  ('Свели-Квели "Умалат", 30%, 0,37 кг, в/у, кг', 115.44),
#  ('Свели-Квели "Умалат", 30%, 0,37 кг, в/у, кг', 115.44),
#  ('Сливки Panna Fresca "Unagrande", 38%, 0,5 л, пл/с, кг', 58),
#  ('Сливки Panna Fresca "Unagrande", 38%, 0,5 л, пл/с, кг', 58),
#  ('Сулугуни  "Умалат", 45%, 0,37 кг, т/ф, (6 шт), кг', 444.74),
#  ('Сулугуни  "Умалат", 45%, 0,37 кг, т/ф, (6 шт), кг', 444.74),
#  ('Сулугуни "Маркет Перекресток", 45%, 0,28 кг, т/ф, кг', 78.4),
#  ('Сулугуни "Маркет Перекресток", 45%, 0,28 кг, т/ф, кг', 78.4),
#  ('Сулугуни "Умалат" (для хачапури), 45%, 0,12 кг, ф/п, кг', 149.04),
#  ('Сулугуни "Умалат" (для хачапури), 45%, 0,12 кг, ф/п, кг', 149.04),
#  ('Сулугуни "Умалат", 45%, 0,2 кг, т/ф, (9 шт), кг', 149.4),
#  ('Сулугуни "Умалат", 45%, 0,2 кг, т/ф, (9 шт), кг', 149.4),
#  ('Сулугуни "Умалат", 45%, 0,28 кг, т/ф, (8 шт), кг', 2540.16),
#  ('Сулугуни "Умалат", 45%, 0,28 кг, т/ф, (8 шт), кг', 2540.16),
#  ('Сулугуни палочки "Умалат", 45%, 0,12 кг, т/ф (10 шт.), кг', 706.2),
#  ('Сулугуни палочки "Умалат", 45%, 0,12 кг, т/ф (10 шт.), кг', 706.2),
#  ('Сыр Черкесский "Умалат", 45%, 0,28 кг, т/ф, кг', 515.2),
#  ('Сыр Черкесский "Умалат", 45%, 0,28 кг, т/ф, кг', 515.2),
#  ('Сыр Черкесский "Умалат", 45%, кг, т/ф, ВЕС, кг', 4.32),
#  ('Сыр Черкесский "Умалат", 45%, кг, т/ф, ВЕС, кг', 4.32),
#  ('Творожный "Pretto", 65%, 0,18 кг, пл/с, кг', 224.64),
#  ('Творожный "Pretto", 65%, 0,18 кг, пл/с, кг', 224.64),
#  ('Четук "Умалат", 45%, 0,37 кг, в/у, кг', 178.34),
#  ('Четук "Умалат", 45%, 0,37 кг, в/у, кг', 178.34)]

# %%
list(zip(*tmp.values.tolist()))
# Out:
# [('Кавказский "Умалат" (Перекресток), 45%, кг, в/у', 1098.6, 1455),
#  ('Кавказский "Умалат" (Окей), 45%, кг, в/у', -225, 0),
#  ('Кавказский "Умалат" (Тандер), 45%, кг , в/у', 213, 972),
#  ('Кавказский "Умалат" (Метро), 45%, кг, в/у', 0, 102),
#  ('Кавказский "Умалат", 45%, 0,37 кг, в/у', -77.70000000000005, 1252.08),
#  ('Кавказский "Глобус", 45%, кг, в/у', -42, 0),
#  ('Кавказский "Умалат", 45%, кг, в/у', -16, 12),
#  ('Сыр Черкесский "Умалат", 45%, 0,28 кг, т/ф', -20.159999999999968, 712.32),
#  ('Сыр Черкесский "Умалат", 45%, кг, т/ф, ВЕС', -3.759999999999998, 49.28),
#  ('Сыр Черкесский "Умалат" (БИЛЛА), 45%, т/ф, ВЕС', 0, 0),
#  ('Сыр Черкесский "Умалат" (ДИКСИ), 45%, т/ф, ВЕС', 0, 0),
#  ('Свели-Квели "Умалат", 30%, 0,37 кг, в/у', -106.55999999999999, 26.64),
#  ('Четук "Умалат", 45%, 0,37 кг, в/у', -172.42000000000002, 26.64),
#  ('Качорикотта "Unagrande", 45%, 0,37 кг, в/у', -74, 14.8),
#  ('Рикотта "Pretto" (зернистая), 30%, 0,37 кг, в/у',
#   -150.95999999999998,
#   23.68),
#  ('Сулугуни "Маркет Перекресток", 45%, 0,28 кг, т/ф',
#   13.439999999999998,
#   91.84),
#  ('Сулугуни "ВкусВилл", 45%, 0,28 кг, т/ф', -195.04, 8.96),
#  ('Сулугуни "Умалат", 45%, 0,28 кг, т/ф, (8 шт)',
#   -1547.8399999999992,
#   6294.400000000001),
#  ('Сулугуни "Умалат", 45%, 0,2 кг, т/ф, (9 шт)', 214.2, 387),
#  ('Сулугуни палочки "Умалат", 45%, 0,12 кг, т/ф (10 шт.)',
#   -521.4000000000001,
#   493.2),
#  ('Сулугуни "Умалат" (для хачапури), 45%, 0,12 кг, ф/п', -270.24, 8.4),
#  ('Сулугуни кубики "ВкусВилл", 45%, 0,12 кг, ф/п', 0, 0),
#  ('Сулугуни  "Умалат", 45%, 0,37 кг, т/ф, (6 шт)', -231.62, 703.74),
#  ('Моцарелла для пиццы «Fine Life», 45%, 0,37 кг, т/ф, (6 шт)', 48.84, 122.1),
#  ('Моцарелла для пиццы "Unagrande", 45%, 0,46 кг, в/у, (8 шт)',
#   1902.5600000000004,
#   4474.88),
#  ('Моцарелла палочки "Unagrande", 45%, 0,12 кг, т/ф', -279, 0),
#  ('Моцарелла палочки "Бонджорно", 45%, 0,12 кг, т/ф', -1.2000000000000002, 6),
#  ('Моцарелла палочки "ВкусВилл", 45%, 0,12 кг, т/ф', -938.4, 0),
#  ('Моцарелла для сэндвичей "Unagrande", 45%, 0,28 кг, т/ф, (8 шт)',
#   -215.04,
#   206.08),
#  ('Моцарелла без лактозы для сэндвичей "Unagrande", 45%, 0,28 кг, т/ф',
#   109.2,
#   194.88),
#  ('Моцарелла "Pretto", 45%, 1,2 кг, в/у', -998.3999999999999, 1267.2),
#  ('Моцарелла для пиццы "Pretto", 45%, 0,46 кг, т/ф, (8 шт)',
#   114.07999999999998,
#   445.28),
#  ('Моцарелла "Pretto" (для бутербродов), 45%, 0,2 кг, т/ф, (9 шт)',
#   235.79999999999973,
#   3520.7999999999997),
#  ('Моцарелла для пиццы "Фермерская коллекция", 45%, 0,2 кг, т/ф', -129.6, 0),
#  ('Моцарелла "Unagrande", 45%, 3 кг, пл/л', -570, 0),
#  ('Моцарелла "Unagrande", 45%, 0,12 кг, ф/п (кубики)',
#   -8.399999999999999,
#   26.4),
#  ('Моцарелла шары "Metro Chef", 45%, кг, в/у', 303.6, 837.2),
#  ('Качокавалло "Unagrande", 45%, 0,26 кг, в/у, (8 шт)', -226.72, 18.72),
#  ('Качокавалло "Unagrande", 45%, кг', -12.399999999999999, 9),
#  ('Качокавалло "Unagrande" (ОК), 45%, кг', -12.600000000000001, 4.5),
#  ('Качокавалло "Unagrande" (Метро), 45%, кг', 0, 0),
#  ('Моцарелла палочки 7,5 гр Эсперсен, 45%, кг, пл/л', 0, 0),
#  ('Моцарелла (палочки), 45%, кг, пл/л', 0, 0),
#  ('Моцарелла Фиор ди латте в воде "Unagrande", 50%, 0,125 кг, ф/п, (8 шт)',
#   -336,
#   266),
#  ('Моцарелла в воде Фиор Ди Латте без лактозы “Unagrande", 45%, 0,125 кг, ф/п, (8 шт)',
#   -47,
#   80),
#  ('Моцарелла Фиор Ди Латте в воде "Pretto", 45%, 0,125 кг, ф/п, (8 шт)',
#   -10.5,
#   112),
#  ('Моцарелла Фиор Ди Латте в воде "Pretto", 45%, 0,1 кг, ф/п, (8 шт)',
#   -446.3999999999999,
#   283.2),
#  ('Моцарелла Фиор ди Латте в воде "Ваш выбор", 50%, 0,1 кг, ф/п', -99.6, 0),
#  ('Моцарелла Фиор ди Латте в воде "Красная птица", 45%, 0,125 кг, ф/п',
#   -157.5,
#   198),
#  ('Моцарелла Фиор ди латте в воде "Fine Life", 45%, 0,125 кг, ф/п', -43.5, 27),
#  ('Моцарелла в воде Фиор Ди Латте "Orecchio Oro", 45%, 0,1 кг, ф/п', 0, 0),
#  ('Моцарелла в воде Фиор Ди Латте без лактозы "ВкусВилл", 45%, 0,125 кг, ф/п (8 шт)',
#   0,
#   490),
#  ('Моцарелла сердечки в воде "Unagrande", 45%, 0,125 кг, ф/п, (8 шт)',
#   -25,
#   22),
#  ('Моцарелла Грандиоза в воде "Unagrande", 50%, 0,2 кг, ф/п', -124.8, 19.2),
#  ('Моцарелла Чильеджина в воде "Unagrande", 50%, 0,125, ф/п, (8 шт)',
#   -1091,
#   1043),
#  ('Моцарелла в воде Чильеджина без лактозы "Unagrande", 45%, 0,125 кг, ф/п',
#   32,
#   37),
#  ('Моцарелла Чильеджина в воде "Pretto", 45%, 0,1 кг, ф/п, (8 шт)',
#   -675.1999999999999,
#   757.6),
#  ('Моцарелла Чильеджина в воде "Fine Life", 45%, 0,125 кг, ф/п', -34.5, 25.5),
#  ('Моцарелла в воде Чильеджина "Orecchio Oro", 45%, 0,1 кг, ф/п', 0, 0),
#  ('Моцарелла Чильеджина в воде "Ваш выбор", 50%, 0,1 кг, ф/п', -157.2, 0),
#  ('Моцарелла Чильеджина в воде "Красная птица", 45%, 0,125 кг, ф/п',
#   -85.5,
#   339),
#  ('Рикотта "Unagrande", 50%, 0,25 кг, пл/с', -517.5, 438),
#  ('Рикотта "Unagrande", 50%, 0,5 кг, пл/с', 69, 165),
#  ('Рикотта "Unagrande Professionale", 45%, 0,5 кг, пл/с', 9, 45),
#  ('Рикотта с шоколадом "Unagrande", 30%, 0,18 кг, пл/с', -300.24, 139.32),
#  ('Рикотта с шоколадом "Unagrande", 30%, 0,14 кг, пл/с',
#   4.200000000000017,
#   233.52),
#  ('Рикотта сицилийская "Unagrande", 55%, 0,3 кг, пл/с',
#   203.40000000000003,
#   624.6),
#  ('Рикотта сицилийская "Unagrande", 55%, ВЕС, пл/с', 21.6, 21.6),
#  ('Рикотта с шоколадом "ВкусВилл", 30%, 0,14 кг, пл/с',
#   -335.15999999999997,
#   10.92),
#  ('Рикотта "Pretto", 45%, 0,5 кг, пл/с', -17625, 192),
#  ('Рикотта "Pretto", 45%, 0,2 кг, пл/с', -55.20000000000027, 2829.6),
#  ('Рикотта "Фермерская коллекция", 45%, 0,2 кг, пл/с',
#   10.799999999999983,
#   154.79999999999998),
#  ('Рикотта "Избёнка", 45%, 0,18 кг, пл/с (6 шт)',
#   47.52000000000021,
#   1667.5200000000002),
#  ('Рикотта "Красная птица", 30%,  0,25 кг, пл/с (6 шт)', 7.5, 336),
#  ('Рикотта "SPAR", 30%, 0,2 кг, пл/с (6 шт)', 1.2, 1.2),
#  ('Рикотта с ванилью "Бонджорно", 30%, 0,2 кг, пл/с', -143.2, 13.2),
#  ('Рикотта с шоколадом "Бонджорно", 30%, 0,2 кг, пл/с', 26, 150),
#  ('Рикотта шоколадно-ореховая "Бонджорно", 35%, 0,2 кг, пл/с',
#   10.400000000000006,
#   116.4),
#  ('Рикотта "Глобус", 45%, 0,25 кг, пл/с', 46.5, 54),
#  ('Сливки Panna Fresca "Unagrande", 38%, 0,5 л, пл/с', 38, 210),
#  ('Кремчиз № 1 "Unagrande Professionale", 70%, 0,5 кг, пл/с', -36, 51),
#  ('Кремчиз "Pretto", 75%, 0,2 кг, пл/с', 128.4, 349.2),
#  ('Кремчиз "Избёнка", 70%, 0,18 кг, пл/с (6шт)', -90.72000000000003, 1032.48),
#  ('Кремчиз "Фермерская коллекция", 75%, 0,2 кг, пл/с', 69.6, 129.6),
#  ('Кремчиз "Unagrande", 70%, 0,18 кг, пл/с',
#   -652.3199999999999,
#   158.76000000000002),
#  ('Творожный "Фермерская коллекция", 65%,0,18 кг,пл/с', 8.64, 8.64),
#  ('Творожный "Pretto", 65%, 0,18 кг, пл/с', 56.15999999999997, 375.84),
#  ('Робиола "Избёнка", 65%, 0,18 кг, пл/с (6 шт)', 113.4, 113.4),
#  ('Робиола "Unagrande", 65%, 0,18 кг, пл/с', 114.47999999999999, 205.2),
#  ('Маскарпоне "Unagrande", 80%, 0,25 кг, пл/с', -589.5, 1123.5),
#  ('Маскарпоне "Pretto", 80%, 0,25 кг, пл/с', -490.5, 3424.5),
#  ('Маскарпоне "Pretto", 80%, 0,5 кг, пл/с', 429, 1854),
#  ('Маскарпоне "Красная птица", 80%,  0,25 кг, пл/с, (6 шт)', 228, 717),
#  ('Маскарпоне "ВкусВилл", 80%, 0,25 кг, пл/с (6 шт)', -270, 450),
#  ('Маскарпоне "Глобус", 80%, 0,25 кг, пл/с', 24, 45),
#  ('Маскарпоне "Unаgrande", 80%, 0,5 кг, пл/с', -186, 360),
#  ('Маскарпоне с шоколадом "Бонджорно", 50%, 0,2 кг, пл/с',
#   -43.599999999999994,
#   43.2),
#  ('Маскарпоне с шоколадом "Unagrande", 50%, 0,18 кг, пл/с', 71.28, 240.84),
#  ('Масло сливочное "Умалат", 72,5%  0,5 кг, к/к', 618, 1089),
#  ('Масло сливочное "Умалат", 72,5%, 2 кг, к/к', 642, 1068),
#  ('Масло сладко-сливочное традиционное 84%, 2 кг, кор (3 вложения)', 582, 582),
#  ('Масло сладко-сливочное традиционное "Unagrande", 82,5%, 0,5 кг, к/к',
#   219,
#   318),
#  ('Масло сладко-сливочное традиционное солёное "Unagrande", 82,5%, 0,5 кг, к/к',
#   261,
#   402),
#  ('Масло сладко-сливочное Традиционное, 82,5%, 2 кг, к/к', 360, 750),
#  ('Некондиционная продукция', 0, 0),
#  ('п/ф Рикотта промышленная', 0, nan),
#  ('П/ф Качокавалло 45%, кг', 0, nan),
#  ('П/ф Качокавалло 45% большие головки', 0, nan),
#  ('Дата выработки продукции:',
#   'Фактические остатки на складах - Заявлено, кг:',
#   'Фактические остатки на складах, ИТОГО, кг, в т.ч.:')]

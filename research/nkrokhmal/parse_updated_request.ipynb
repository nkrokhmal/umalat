# %%
import re
import pandas as pd
import formulas

# %%
if "blah" not in "hah blah hah": 
    print('1')

# %%
if "blah" in "hah blah hah": 
    print('1')
# Out:
# 1

# %%
x = 'hello, hi. how are'
re.split(', |. | ', x)
# Out:
# ['hello', 'hi', 'ho', 'are']

# %%
xx = 2 * [8000]

# %%
xx + 5 * [6000]
# Out:
# [8000, 8000, 6000, 6000, 6000, 6000, 6000]

# %%
model = formulas.ExcelModel().loads(r'plan_2020-11-24.xlsx')

# %%
model.calculate()
# Out:
# Solution([("'[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A1",
#            <Ranges>('[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A1)=[['Форм фактор']]),
#           ("'[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A17",
#            <Ranges>('[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A17)=[['Сулугуни']]),
#           ("'[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A2",
#            <Ranges>('[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A2)=[['Для пиццы']]),
#           ("'[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A28",
#            <Ranges>('[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A28)=[['Моцарелла']]),
#           ("'[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A33",
#            <Ranges>('[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A33)=[['Фиор ди Латте']]),
#           ("'[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A46",
#            <Ranges>('[PLAN_2020-11-24.XLSX]ПЛАНИРОВАНИЕ СУТОЧНОЕ'!A46)=[['Качокавалло']]),
# ...

# %%
model.

# %%
model.write(dirpath='1')
# Out:
# {'PLAN_2020-11-24.XLSX': {Book: <openpyxl.workbook.workbook.Workbook at 0x7fd39695b470>}}

# %%
df = pd.read_excel(r'plan_2020-11-24.xlsx', sheet_name='планирование суточное')

# %%
wb = load_workbook(filename=, data_only=True)

# %%
df[df[df.columns[9]].notna()][df.columns[9:13]]
# Out:
#                                 Unnamed: 9  Unnamed: 10  Расчет  План
# 0    2.7% варка, Альче, Лактоза True, Id 1          NaN     NaN   NaN
# 1   2.7% варка, Альче, Лактоза False, Id 3          NaN     NaN   NaN
# 2    2.7% варка, Сакко, Лактоза True, Id 2          NaN     NaN   NaN
# 4                              Объем варки          NaN   850.0   NaN
# 15   2.7% варка, Сакко, Лактоза True, Id 2          NaN     NaN   NaN
# 16   2.7% варка, Альче, Лактоза True, Id 1          NaN     NaN   NaN
# 18                             Объем варки          NaN   850.0   NaN
# 26   2.7% варка, Альче, Лактоза True, Id 1          NaN     NaN   NaN
# 28                             Объем варки          NaN   850.0   NaN
# 31   3.6% варка, Альче, Лактоза True, Id 9          NaN     NaN   NaN
# 32   3.3% варка, Сакко, Лактоза True, Id 6          NaN     NaN   NaN
# 33  3.3% варка, Альче, Лактоза False, Id 7          NaN     NaN   NaN
# ...

# %%
import pandas as pd

# %%
path = r'/home/nkrokhmal/Desktop/umalat/app/data/params_1020.xlsx'

# %%
df = pd.read_excel(path)
df.head()
# Out:
#    Unnamed: 0                                       Название SKU  Процент  \
# 0           0  Моцарелла "Pretto" (для бутербродов), 45%, 0,2...      2.7
# 1           1               Моцарелла "Pretto", 45%, 1,2 кг, в/у      2.7
# 2           2  Моцарелла "Unagrande", 45%, 0,12 кг, ф/п (кубики)      2.7
# 3           3             Моцарелла "Unagrande", 45%, 3 кг, пл/л      2.7
# 4           4                 Моцарелла (палочки), 45%, кг, пл/л      2.7
#
#   Наличие лактозы Тип закваски Название форм фактора Линия Имя бренда  \
# 0              Да        Сакко             Для пиццы  Соль     Pretto
# 1              Да        Сакко             Для пиццы  Соль     Pretto
# 2              Да        Альче             Моцарелла  Соль  Unagrande
# 3              Да        Альче             Моцарелла  Соль  Unagrande
# 4              Да        Альче             Моцарелла  Соль   Эсперсон
#
#    Вес нетто  Коробки  ...  Скорость упаковки  Охлаждение 1(для воды)  \
# ...

# %%
df[(df['Процент'] == 3.3) & (df['Тип закваски'] == 'Сакко')]
# Out:
#     Unnamed: 0                                       Название SKU  Процент  \
# 39          39  Моцарелла Фиор Ди Латте в воде "Pretto", 45%, ...      3.3
# 40          40  Моцарелла Фиор Ди Латте в воде "Pretto", 45%, ...      3.3
# 41          41  Моцарелла Фиор ди Латте в воде "Ваш выбор", 50...      3.3
# 42          42  Моцарелла Фиор ди Латте в воде "Красная птица"...      3.3
# 43          43  Моцарелла Фиор ди латте в воде "Fine Life", 45...      3.3
# 44          44  Моцарелла в воде Фиор ди Латте "Aventino", 45%...      3.3
# 45          45  Моцарелла в воде Фиор Ди Латте "Orecchio Oro",...      3.3
# 46          46  Моцарелла в воде Фиор Ди Латте "Каждый день", ...      3.3
# 53          53  Моцарелла Чильеджина в воде "Pretto", 45%, 0,1...      3.3
# 54          54  Моцарелла в воде Чильеджина "Aventino", 45%, 0...      3.3
# 55          55  Моцарелла Чильеджина в воде "Fine Life", 45%, ...      3.3
# ...

# %%
df[(df['Процент'] == 3.3) & (df['Тип закваски'] == 'Сакко')].iloc[-1, 1]
# Out:
# 'Моцарелла Чильеджина в воде "Красная птица", 45%, 0,125/0,225 кг, ф/п'

# %%
df.loc[df['Линия'] == 'Вода', 'Время нарезки'] += 5

# %%
df[df['Линия'] == 'Вода']
# Out:
#     Unnamed: 0                                       Название SKU  Процент  \
# 6            6  Моцарелла в воде Фиор Ди Латте без лактозы "Un...      3.3
# 37          37  Моцарелла Фиор ди латте в воде "Unagrande", 50...      3.6
# 38          38  Моцарелла в воде Фиор Ди Латте без лактозы “Un...      3.3
# 39          39  Моцарелла Фиор Ди Латте в воде "Pretto", 45%, ...      3.3
# 40          40  Моцарелла Фиор Ди Латте в воде "Pretto", 45%, ...      3.3
# 41          41  Моцарелла Фиор ди Латте в воде "Ваш выбор", 50...      3.3
# 42          42  Моцарелла Фиор ди Латте в воде "Красная птица"...      3.3
# 43          43  Моцарелла Фиор ди латте в воде "Fine Life", 45...      3.3
# 44          44  Моцарелла в воде Фиор ди Латте "Aventino", 45%...      3.3
# 45          45  Моцарелла в воде Фиор Ди Латте "Orecchio Oro",...      3.3
# 46          46  Моцарелла в воде Фиор Ди Латте "Каждый день", ...      3.3
# ...

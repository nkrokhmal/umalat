# %%
import sys
sys.path.append(r'/home/nkrokhmal/Desktop/MyProjects/SergeyProject/umalat-project/prod')
from app.models import *
from app.models import Boiling as BoilingModel
from app.models import Termizator as TermizatorModel

from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# sqlite_filepath = '/home/akadaner/Desktop/data.sqlite'
sqlite_filepath = r"/home/nkrokhmal/Desktop/MyProjects/SergeyProject/umalat-project/prod/data.sqlite"
engine = create_engine(f"sqlite:///{sqlite_filepath}")
Session = sessionmaker()
Session.configure(bind=engine)
session = Session()

def cast_sku(obj):
    if isinstance(obj, SKU):
        return obj
    elif isinstance(obj, (str, int)):
        obj = str(obj)
        return session.query(SKU).filter(SKU.id == obj).first()
    else:
        raise Exception('Unknown sku type')
        
def cast_boiling(obj):
    if isinstance(obj, Boiling):
        return obj
    elif isinstance(obj, (str, int)):
        obj = str(obj)
        return session.query(Boiling).filter(Boiling.id == obj).first()
    else:
        raise Exception('Unknown boiling type')

# %%
from app.utils.excel_client import *
import datetime
import os

# %%
datetime.datetime.strptime('01.01.2020', '%d.%m.%Y')
[{"BoilingId": 6, "BoilingCount": 1.0, "BoilingWeights": [8000], 
  "SKUVolumes": {"24": 199, "23": 190.3999999999999, "26": 75.6, "27": 40.5, "22": 76.5}}
# Out:
#   File "<ipython-input-6-36f7d7de9aec>", line 3
#     "SKUVolumes": {"24": 199, "23": 190.3999999999999, "26": 75.6, "27": 40.5, "22": 76.5}}
#                                                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
def create_json(path):
    try:
        basename = os.path.basename(path)
        date_str = os.path.splitext(basename)[0]
        date = datetime.datetime.strptime(date_str, '%d.%m.%y')

        response = {'Date': date, 'WeekDay': date.weekday(), 'Boilings': []}
        result_list = []
        skus = session.query(SKU).all()
        group_items = [{
            "Ferment": x.boiling.ferment,
            "IsLactose": x.boiling.is_lactose,
            "Percent": x.boiling.percent,
            "FormFactor": x.form_factor
        } for x in skus.copy()]
        group_items = [dict(x) for x in set(frozenset(d.items()) for d in group_items)]

        df = pd.read_excel(path, index_col=0)
        df_save = df.copy()
        df.columns = range(df.shape[1])
        df = df[df.loc['Дата выработки продукции:'].dropna().index]
        df = df.loc[['Дата выработки продукции:',
                     'Заявлено всего, кг:',
                     'Фактические остатки на складах - Заявлено, кг:',
                     'Нормативные остатки, кг']].fillna(0).iloc[:, :-1]
        data = list(zip(*df.values.tolist()))

        full_list = []
        print('Creating full list')
        sku_for_create = []
        for item in data:
            sku = [x for x in skus if x.name == item[0]]
            if sku is not None and len(sku) > 0:
                full_list.append({
                    "SKU": sku[0],
                    "Request": item[2]
                })
            else:
                sku_for_create.append(item[0])
        print('Group items')
        for group_item in group_items:
            group_sku = [x for x in full_list if
                                 x["SKU"].boiling.ferment == group_item["Ferment"] and
                                 x["SKU"].boiling.is_lactose == group_item["IsLactose"] and
                                 x["SKU"].boiling.percent == group_item["Percent"] and
                                 x["SKU"].form_factor == group_item["FormFactor"]]
            if group_sku is not None and len(group_sku) > 0:
                output_weight = group_sku[0]["SKU"].output_per_ton
                request_weight = sum([x["Request"] for x in group_sku if x["Request"] < 0])
                result_list.append({
                    "GroupSKU": group_sku,
                    "BoilingId": group_sku[0]["SKU"].boiling_id,
                    "BoilingCount": - request_weight / output_weight
                })
        result_list = [x for x in result_list if round(x['BoilingCount']) > 0]
        print(len(result_list))
        for res in result_list:
            tmp = {}
            tmp['BoilingId'] = res['BoilingId']
            tmp['BoilingCount'] = round(res['BoilingCount'])
            tmp['BoilingWeights'] = round(res['BoilingCount']) * [8000]
            tmp_list = []
            for sku in res['GroupSKU']:
                if sku["Request"] < 0:
                    tmp_list.append({sku["SKU"].id: sku["Request"]})
            tmp['SKUVolumes'] = tmp_list
            response['Boilings'].append(tmp)
            
        saved_path = os.path.join(os.path.dirname(path), date_str + '.txt')
        print(saved_path)
        with open(saved_path, 'w') as outfile:
            def default(o):
                if isinstance(o, (datetime.date, datetime.datetime)):
                    return o.isoformat()
            json.dump(response, outfile, default=default)
        
#         return response
    except Exception as e:
        print('Exception occured {}'.format(e))

# %%
create_json('/home/nkrokhmal/Desktop/MyProjects/SergeyProject/umalat-project/prod/research/nkrokhmal/30.09.20.xlsx')
# Out:
# Creating full list
# Group items
# 5
# /home/nkrokhmal/Desktop/MyProjects/SergeyProject/umalat-project/prod/research/nkrokhmal/30.09.20.txt

# %%
directory = '/home/nkrokhmal/Downloads/2020 scheduling/2020'
t = os.walk(directory)
for folder in [x[0] for x in os.walk(directory)][1:]:
    filenames = [x[2] for x in os.walk(folder)][0]
    for filename in filenames:
        filename_fullpath = os.path.join(folder, filename)
        print(filename_fullpath)
        create_json(filename_fullpath)
# Out:
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/08.02.20.xlsx
# Creating full list
# Group items
# 4
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/08.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/15.02.20.xlsx
# Creating full list
# Group items
# 5
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/15.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/25.02.20.xlsx
# Creating full list
# Group items
# 1
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/25.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/01.02.20.xlsx
# Creating full list
# Group items
# 4
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/01.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/12.02.20.xlsx
# Creating full list
# Group items
# 1
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/12.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/29.02.20.xlsx
# Creating full list
# Group items
# 4
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/29.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/11.02.20.xlsx
# Creating full list
# Group items
# 4
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/11.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/19.02.20.xlsx
# Creating full list
# Group items
# 3
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/19.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/18.02.20.xlsx
# Creating full list
# Group items
# 3
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/18.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/28.02.20.xlsx
# Creating full list
# Group items
# 5
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/28.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/21.02.20.xlsx
# Creating full list
# Group items
# 3
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/21.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/03.02.20.xlsx
# Creating full list
# Group items
# 4
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/03.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/07.02.20.xlsx
# Creating full list
# Group items
# 4
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/07.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/17.02.20.xlsx
# Creating full list
# Group items
# 2
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/17.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/14.02.20.xlsx
# Creating full list
# Group items
# 5
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/14.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/27.02.20.xlsx
# Creating full list
# Group items
# 3
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/27.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/23.02.20.xlsx
# Creating full list
# Group items
# 2
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/23.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/04.02.20.xlsx
# Creating full list
# Group items
# 3
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/04.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/16.02.20.xlsx
# Creating full list
# Group items
# 2
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/16.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/05.02.20.xlsx
# Creating full list
# Group items
# 0
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/05.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/09.02.20.xlsx
# Creating full list
# Group items
# 3
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/09.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/02.02.20.xlsx
# Creating full list
# Group items
# 4
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/02.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/22.02.20.xlsx
# Creating full list
# Group items
# 2
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/22.02.20.txt
# /home/nkrokhmal/Downloads/2020 scheduling/2020/февраль/Копия 29.02.20.xlsx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-17d01dc8a083> in <module>
#       6         filename_fullpath = os.path.join(folder, filename)
#       7         print(filename_fullpath)
# ----> 8         create_json(filename_fullpath)
#       9
#
# <ipython-input-37-577d9be5ae4f> in create_json(path)
#       2     basename = os.path.basename(path)
#       3     date_str = os.path.splitext(basename)[0]
# ----> 4     date = datetime.datetime.strptime(date_str, '%d.%m.%y')
#       5
#       6     response = {'Date': date, 'WeekDay': date.weekday(), 'Boilings': []}
#
# /usr/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# /usr/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data 'Копия 29.02.20' does not match format '%d.%m.%y'

# %%
[x[0] for x in os.walk(directory)]
# Out:
# ['/home/nkrokhmal/Downloads/2020 scheduling/2020',
#  '/home/nkrokhmal/Downloads/2020 scheduling/2020/февраль',
#  '/home/nkrokhmal/Downloads/2020 scheduling/2020/август',
#  '/home/nkrokhmal/Downloads/2020 scheduling/2020/Сентябрь',
#  '/home/nkrokhmal/Downloads/2020 scheduling/2020/июнь',
#  '/home/nkrokhmal/Downloads/2020 scheduling/2020/май',
#  '/home/nkrokhmal/Downloads/2020 scheduling/2020/январь',
#  '/home/nkrokhmal/Downloads/2020 scheduling/2020/апрель',
#  '/home/nkrokhmal/Downloads/2020 scheduling/2020/Март',
#  '/home/nkrokhmal/Downloads/2020 scheduling/2020/Июль']

# %%
[x[2] for x in os.walk('/home/nkrokhmal/Downloads/2020 scheduling/2020/Июль')]
# Out:
# [['17.07.20.xlsx',
#   '18.07.20.xlsx',
#   '07.07.20.xlsx',
#   '11.07.20 ( расчет эффективности).xlsx',
#   '31.07.20.xlsx',
#   '10.07.20.xlsx',
#   '15.07.20.xlsx',
#   '05.07.20.xlsx',
#   '20.07.20.xlsx',
#   '14.07.20.xlsx',
#   '29.07.20.xlsx',
#   '28.07.20.xlsx',
#   '11.07.20.xlsx',
#   '26.07.20.xlsx',
#   '04.07.20.xlsx',
#   '01.07.20.xlsx',
#   '21.07.20.xlsx',
#   '10.07.20 (1).xlsx',
#   '22.07.20.xlsx',
#   '03.07.20.xlsx',
#   '12.07.20.xlsx',
#   '08.07.20.xlsx',
#   '25.07.20.xlsx',
#   '19.07.20.xlsx',
#   '24.07.20.xlsx']]
